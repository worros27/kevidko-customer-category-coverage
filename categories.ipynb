# %%
import pandas as pd

# 1. 读取数据
df = pd.read_csv('sale_cate.csv')

# 2. 创建“已购买”标记列
df['Bought'] = 1

# 3. 去重，只保留“客户 - 类别”的唯一组合
df_unique = df[['Name', 'Product_Category', 'Bought']].drop_duplicates()

# 4. 构建 客户 x 产品类别 的矩阵
pivot = df_unique.pivot_table(
    index='Name',
    columns='Product_Category',
    values='Bought',
    aggfunc='max',
    fill_value=0
)

# 5. 计算每个产品类别的购买覆盖率（多少客户买过）
category_coverage = pivot.mean().sort_values(ascending=False)

# 6. 设定“热门类别”阈值，例如 80% 客户买过
threshold = 0.75
popular_categories = category_coverage[category_coverage >= threshold].index.tolist()

# 7. 找出这些热门类别中“没买过”的客户
missing_matrix = pivot[popular_categories] == 0

# 8. 整理输出结果：每个热门类别，对应没买过的客户列表
result = {}
for category in popular_categories:
    missing_customers = pivot.index[missing_matrix[category]].tolist()
    if missing_customers:
        result[category] = missing_customers

# 9. 打印结果
for category, customers in result.items():
    print(f"\n🔍 category [{category}] - {len(customers)} customers haven't buy：")
    for customer in customers:
        print(f"   - {customer}")
# Out:
# 🔍 category [Bags] - 22 customers haven't buy：
#    - 626 Commissary
#    - 626 Hospitality Group
#    - ALLEN PACKAGING
#    - American KGP Inc.
#    - And Destroy Coffee
#    - BB Bakery
#    - Baba Small Batch
#    - Beth Jacob Congregation
#    - Beyond The Grind
#    - Borekas Sephardic Pastries- Van Nuys
#    - Borekas Sephardic Pastries- Ventura
#    - Bostons Best Coffee
#    - Bub and Grandma's Pizza
#    - C O D
#    - Castanea Sicilian Cafe
#    - Cento
#    - Cerenzia Foods
#    - Cognoscenti Coffee San Julian
#    - Couplet Coffee
#    - Demitasse Roastery
#    - Elat Supermarket
#    - F & I COHEN
#
# 🔍 category [Packaging] - 24 customers haven't buy：
#    - 626 Commissary
#    - 626 Hospitality Group
#    - A-1 Plus
#    - American KGP Inc.
#    - And Destroy Coffee
#    - Baba Small Batch
#    - Beyond The Grind
#    - Borekas Sephardic Pastries- Ventura
#    - Bostan By Grandma
#    - Bostons Best Coffee
#    - Bridgetown Roti
#    - Bub and Grandma's Pizza
#    - Buena Vida Tea Bar
#    - C O D
#    - Cafe Tondo
#    - Carla's Fresh Market
#    - Castanea Sicilian Cafe
#    - Cognoscenti Coffee San Julian
#    - Cognoscenti Coffee- Culver
#    - Danbi
#    - Demitasse Roastery
#    - Dura Sourcing, INC
#    - El Alteno Wholesale
#    - Escamex
#
# 🔍 category [Lids] - 24 customers haven't buy：
#    - ALLEN PACKAGING
#    - Ace Hotel
#    - American KGP Inc.
#    - Awan- Melrose
#    - Awan- Venice
#    - Awan- West Hollywood
#    - BB Bakery
#    - Baba Small Batch
#    - Beyond The Grind
#    - Bodega, Los Alamos
#    - Bodega-----old Los Alamos (CHG)-----old
#    - Bub and Grandma's Pizza
#    - Carla's Fresh Market
#    - Castanea Sicilian Cafe
#    - Danielle's Glatt Kosher
#    - Demitasse Roastery
#    - Dunsmoor
#    - Dura Sourcing, INC
#    - El Alteno Wholesale
#    - El Chucho
#    - Elat Supermarket
#    - Elite Fish Market
#    - Elite Fresh Fish Wholesale
#    - F & I COHEN

# %%
import pandas as pd

# 1. 读取数据
df = pd.read_csv("Merged_Customer_Category_Table.csv")

# 2. 添加购买标记列
df["Bought"] = 1

# 3. 保留唯一客户 × 品类组合
df_unique = df[["Name", "Product_Category", "Bought"]].drop_duplicates()

# 4. 构建透视表（客户 × 品类）
pivot = df_unique.pivot_table(index='Name', columns='Product_Category', values='Bought', aggfunc='max', fill_value=0)

# 5. 计算每个品类的购买覆盖率（多少客户买过）
category_coverage = pivot.mean()
popular_categories = category_coverage[category_coverage >= 0.76].index.tolist()

# 6. 标记热门品类中哪些客户没买
missing_matrix = pivot[popular_categories] == 0

# 7. 合并客户类型信息
customer_type_map = df[['Name', 'Customer_Category']].drop_duplicates().set_index('Name')['Customer_Category']
pivot['Customer_Type'] = pivot.index.map(customer_type_map)

# 8. 遍历每个客户类型，输出未购买热门品类的客户
result = {}

for ctype in pivot['Customer_Type'].unique():
    group = pivot[pivot['Customer_Type'] == ctype]
    result[ctype] = {}

    for category in popular_categories:
        missing_customers = group.index[group[category] == 0].tolist()
        if missing_customers:
            result[ctype][category] = missing_customers

# 9. 打印结果
for ctype, cat_dict in result.items():
    print(f"\n📂 Customer Type: {ctype}")
    for cat, customers in cat_dict.items():
        print(f"🔸 Category [{cat}] - {len(customers)} customers haven't buy:")
        for name in customers:
            print(f"   - {name}")

# 10. 整理结果为平铺表格格式
output = []

for ctype, cat_dict in result.items():
    for cat, customers in cat_dict.items():
        for name in customers:
            output.append({
                'Customer_Type': ctype,
                'Product_Category': cat,
                'Customer_Name': name
            })

# 转换为 DataFrame
df_output = pd.DataFrame(output)

# 导出为 Excel 文件
df_output.to_excel("Unpurchased_Popular_Categories.xlsx", index=False)
print("✅ 导出完成：Unpurchased_Popular_Categories.xlsx")
# Out:
# 📂 Customer Type: Restaurant – Vietnamese
#
# 📂 Customer Type: Restaurant – Contemporary American
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - 626 Commissary
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - 626 Commissary
#
# 📂 Customer Type: Hospitality Group
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - 626 Hospitality Group
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - 626 Hospitality Group
#
# 📂 Customer Type: Services – General
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - A-1 Plus
#
# 📂 Customer Type: Manufacturing – Packaging
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - ALLEN PACKAGING
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - ALLEN PACKAGING
#
# 📂 Customer Type: Hotel
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Ace Hotel
#
# 📂 Customer Type: Industrial Supplier
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - American KGP Inc.
# 🔸 Category [Lids] - 2 customers haven't buy:
#    - American KGP Inc.
#    - Dura Sourcing, INC
# 🔸 Category [Packaging] - 2 customers haven't buy:
#    - American KGP Inc.
#    - Dura Sourcing, INC
#
# 📂 Customer Type: Cafe / Coffee Shop
# 🔸 Category [Bags] - 4 customers haven't buy:
#    - And Destroy Coffee
#    - Beyond The Grind
#    - Bostons Best Coffee
#    - Couplet Coffee
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Beyond The Grind
# 🔸 Category [Packaging] - 4 customers haven't buy:
#    - And Destroy Coffee
#    - Beyond The Grind
#    - Bostons Best Coffee
#    - Cafe Tondo
#
# 📂 Customer Type: Restaurant – Middle Eastern / Cafe
#
# 📂 Customer Type: Cafe / Coffee Shop – Breakfast & Brunch
#
# 📂 Customer Type: Dessert Shop – Vegan Ice Cream
# 🔸 Category [Lids] - 3 customers haven't buy:
#    - Awan- Melrose
#    - Awan- Venice
#    - Awan- West Hollywood
#
# 📂 Customer Type: Arts & Crafts / Consumer Services
#
# 📂 Customer Type: Restaurant – Middle Eastern
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Bostan By Grandma
#
# 📂 Customer Type: Bakery
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - BB Bakery
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - BB Bakery
#
# 📂 Customer Type: Restaurant – Homestyle / Bakery
#
# 📂 Customer Type: Bakery – Wholesale
#
# 📂 Customer Type: Bakery – Artisan / Wholesale
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - Baba Small Batch
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Baba Small Batch
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Baba Small Batch
#
# 📂 Customer Type: Restaurant – Italian
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - Cento
#
# 📂 Customer Type: Bakery – Specialty
#
# 📂 Customer Type: Bar / Lounge
#
# 📂 Customer Type: Restaurant – American
#
# 📂 Customer Type: Bakery – Bagels
#
# 📂 Customer Type: Wholesale – Grocery
#
# 📂 Customer Type: Religious Institution
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - Beth Jacob Congregation
#
# 📂 Customer Type: Retail – Floral / Gift
#
# 📂 Customer Type: Cafe / Restaurant – Californian Breakfast
#
# 📂 Customer Type: Retail – Grocery
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Bodega, Los Alamos
#
# 📂 Customer Type: To be determined
# 🔸 Category [Bags] - 2 customers haven't buy:
#    - C O D
#    - Cerenzia Foods
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Bodega-----old Los Alamos (CHG)-----old
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - C O D
#
# 📂 Customer Type: Bakery – Ethnic Pastries
# 🔸 Category [Bags] - 2 customers haven't buy:
#    - Borekas Sephardic Pastries- Van Nuys
#    - Borekas Sephardic Pastries- Ventura
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Borekas Sephardic Pastries- Ventura
#
# 📂 Customer Type: Restaurant – Market-Style
#
# 📂 Customer Type: Bakery / Cafe
#
# 📂 Customer Type: Restaurant – Bakery-style
#
# 📂 Customer Type: Restaurant – Indian
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Bridgetown Roti
#
# 📂 Customer Type: Catering Service
#
# 📂 Customer Type: Restaurant – Pizza
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - Bub and Grandma's Pizza
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Bub and Grandma's Pizza
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Bub and Grandma's Pizza
#
# 📂 Customer Type: Cafe / Tea Bar
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Buena Vida Tea Bar
#
# 📂 Customer Type: Restaurant – Vietnamese Sandwiches
#
# 📂 Customer Type: Restaurant – Burgers
#
# 📂 Customer Type: Restaurant – Mediterranean / Pita
#
# 📂 Customer Type: Brewery / Gastropub
#
# 📂 Customer Type: Restaurant – American Bistro & Bar
#
# 📂 Customer Type: Cafe / Coffee Roaster
# 🔸 Category [Bags] - 2 customers haven't buy:
#    - Cognoscenti Coffee San Julian
#    - Demitasse Roastery
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Demitasse Roastery
# 🔸 Category [Packaging] - 3 customers haven't buy:
#    - Cognoscenti Coffee San Julian
#    - Cognoscenti Coffee- Culver
#    - Demitasse Roastery
#
# 📂 Customer Type: Cafe / Brunch Spot
#
# 📂 Customer Type: Retail – Grocery / Market
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Carla's Fresh Market
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Carla's Fresh Market
#
# 📂 Customer Type: Cafe – Sicilian
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - Castanea Sicilian Cafe
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Castanea Sicilian Cafe
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Castanea Sicilian Cafe
#
# 📂 Customer Type: Restaurant – Italian Deli
#
# 📂 Customer Type: Restaurant – Mexican
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - El Chucho
#
# 📂 Customer Type: Manufacturing – Plastics
#
# 📂 Customer Type: Restaurant – Californian
#
# 📂 Customer Type: Market / Grocery
#
# 📂 Customer Type: Restaurant – Korean
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Danbi
#
# 📂 Customer Type: Catering – Kosher
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Danielle's Glatt Kosher
#
# 📂 Customer Type: Restaurant – Asian / Fried Chicken
#
# 📂 Customer Type: Dessert Shop
#
# 📂 Customer Type: Restaurant – Modern Californian
#
# 📂 Customer Type: Cafe / Brunch & Bakery
#
# 📂 Customer Type: Retail – Fashion / Concept Store
#
# 📂 Customer Type: Restaurant – American / Fine Dining
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Dunsmoor
#
# 📂 Customer Type: Wholesale – Hispanic Foods
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - El Alteno Wholesale
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - El Alteno Wholesale
#
# 📂 Customer Type: Supermarket – International
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - Elat Supermarket
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Elat Supermarket
#
# 📂 Customer Type: Supermarket / Grocer
#
# 📂 Customer Type: Seafood Market
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Elite Fish Market
#
# 📂 Customer Type: Wholesale – Seafood
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - Elite Fresh Fish Wholesale
#
# 📂 Customer Type: Wholesale – Mexican Products
# 🔸 Category [Packaging] - 1 customers haven't buy:
#    - Escamex
#
# 📂 Customer Type: Bar / Cocktail Lounge
#
# 📂 Customer Type: Wholesale – General Goods
# 🔸 Category [Bags] - 1 customers haven't buy:
#    - F & I COHEN
# 🔸 Category [Lids] - 1 customers haven't buy:
#    - F & I COHEN
#
# 📂 Customer Type: Restaurant – Jewish Deli
# ✅ 导出完成：Unpurchased_Popular_Categories.xlsx

# %%
import pandas as pd

# 1. 读取数据
df = pd.read_csv("Merged_Customer_Category_Table.csv")
df["Bought"] = 1

# 2. 获取客户-品类唯一组合
df_unique = df[["Name", "Product_Category", "Bought"]].drop_duplicates()

# 3. 透视表（客户 × 品类）
pivot = df_unique.pivot_table(index='Name', columns='Product_Category', values='Bought', aggfunc='max', fill_value=0)

# 4. 品类覆盖率
category_coverage = pivot.mean()
popular_categories = category_coverage[category_coverage >= 0.76]

# 5. 客户类型信息
customer_type_map = df[['Name', 'Customer_Category']].drop_duplicates().set_index('Name')['Customer_Category']
pivot['Customer_Type'] = pivot.index.map(customer_type_map)

# 6. 构建完整行级表格
output = []

for name, row in pivot.iterrows():
    ctype = row["Customer_Type"]
    for cat in popular_categories.index:
        purchased = row[cat]
        output.append({
            "Customer_Name": name,
            "Customer_Type": ctype,
            "Product_Category": cat,
            "Purchased": int(purchased),
            "Category_Coverage": round(popular_categories[cat], 2)
        })

# 7. 转为 DataFrame 并导出
df_output = pd.DataFrame(output)
df_output.to_excel("Customer_Unpurchased_Report.xlsx", index=False)
print("✅ 导出完成：Customer_Unpurchased_Report.xlsx")
# Out:
# ✅ 导出完成：Customer_Unpurchased_Report.xlsx
